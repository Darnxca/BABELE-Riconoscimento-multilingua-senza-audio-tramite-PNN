# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import delle librerie**

# %%
from sklearn.datasets import load_iris

from sklearn import datasets

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score

# %% [markdown]
# # Recupero path di Colab

# %%
directory_progetto = "Progetto BABELE/" #Inserire la directory principale del progetto

path_principale = '/content/drive/Shareddrives/Progetti FVAB 22 23 - VSR & BABELE/Gruppi/Gruppo 22/'+directory_progetto

# %% [markdown]
# ## Caricamento Train - BABELE

# %% [markdown]
# ### Train - distanza Chebyshev

# %%
def carica_train_chebyshev(print_tables=False):

    # Definisci i percorsi e i nomi dei file
    data_folder = '/CSV_DATASET/Train/'
    csv_filename = 'Train_babele_chebyshev.csv'
    full_path = path_principale + data_folder + csv_filename

    # Leggi il file CSV e assegna i dati al dataframe df_train
    df_train = pd.read_csv(full_path)

    # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
    X_train = df_train.drop(columns=['target', 'video-frame'])

    if print_tables:
        # Stampa la matrice delle features X
        print('-' * 50 + ' X_TRAIN ' + '-' * 50)
        display(X_train)

    # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
    Y_train = df_train[['target']]

    if print_tables:
        # Stampa l'array delle etichette Y
        print('-' * 50 + ' Y_TRAIN ' + '-' * 50)
        display(Y_train)

    return X_train, Y_train

# %% [markdown]
# ### Train -  distanza Cityblock

# %%
def carica_train_cityblock(print_tables=False):

  # Definisci i percorsi e i nomi dei file
  data_folder = '/CSV_DATASET/Train/'
  csv_filename = 'Train_babele_cityblock_random6.csv'
  full_path = path_principale + data_folder + csv_filename

  # Leggi il file CSV e assegna i dati al dataframe df_train
  df_train = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
  X_train = df_train.drop(columns=['target', 'video-frame'])

  if print_tables:
      # Stampa la matrice delle features X
      print('-' * 50 + ' X_TRAIN ' + '-' * 50)
      display(X_train)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_train = df_train[['target']]

  if print_tables:
      # Stampa l'array delle etichette Y
      print('-' * 50 + ' Y_TRAIN ' + '-' * 50)
      display(Y_train)

  return X_train, Y_train

# %% [markdown]
# ### Train - distanza Coseno

# %%
def carica_train_coseno(print_tables=False):

  # Definisci i percorsi e i nomi dei file
  data_folder = 'CSV_DATASET/Train/'
  csv_filename = 'Train_babele_cosine.csv'
  full_path = path_principale + data_folder + csv_filename

  # Leggi il file CSV e assegna i dati al dataframe df_train
  df_train = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
  X_train = df_train.drop(columns=['target', 'video-frame'])

  # Leggi il file CSV e assegna i dati al dataframe df_train
  df_train = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
  X_train = df_train.drop(columns=['target', 'video-frame'])

  if print_tables:
       # Stampa la matrice delle features X
       print('-' * 50 + ' X_TRAIN ' + '-' * 50)
       display(X_train)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_train = df_train[['target']]

  if print_tables:
      # Stampa l'array delle etichette Y
      print('-' * 50 + ' Y_TRAIN ' + '-' * 50)
      display(Y_train)

  return X_train, Y_train

# %% [markdown]
# ### Train - distanza Euclidea

# %%
def carica_train_euclidea(print_tables=False):

  # Definisci i percorsi e i nomi dei file
  data_folder = '/CSV_DATASET/Train/'
  csv_filename = 'Train_babele_euclidean.csv'
  full_path = path_principale + data_folder + csv_filename

  # Leggi il file CSV e assegna i dati al dataframe df_train
  df_train = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
  X_train = df_train.drop(columns=['target', 'video-frame'])

  if print_tables:
      # Stampa la matrice delle features X
      print('-' * 50 + ' X_TRAIN ' + '-' * 50)
      display(X_train)


  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_train = df_train[['target']]

  if print_tables:
      # Stampa l'array delle etichette Y
      print('-' * 50 + ' Y_TRAIN ' + '-' * 50)
      display(Y_train)

  return X_train, Y_train

# %% [markdown]
# ### Train - X vs Mondo

# %%
def carica_train_XvsMondo(lingua, print_tables=False):

    lingua = lingua.lower() #Pretendo l'input in minuscolo..

    # Definisci il percorso e il nome del file CSV di training
    data_folder = '/CSV_DATASET/Train/'
    if lingua in ['francese', 'giapponese', 'inglese', 'tedesco', 'italiano', 'olandese', 'russo', 'spagnolo']:
        csv_filename = f'Train_babele_cityblock_{lingua}VsMondo.csv'
    else:
        raise ValueError("Lingua non valida. Hai inserito " + lingua)
    full_path = path_principale + data_folder + csv_filename

    # Leggi il file CSV e assegna i dati al dataframe df_train
    df_train = pd.read_csv(full_path)

    # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
    X_train = df_train.drop(columns=['target', 'video-frame'])

    if print_tables:
        # Stampa la matrice delle features X
        print('-' * 50 + ' X_TRAIN ' + '-' * 50)
        display(X_train)

    # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
    Y_train = df_train[['target']]

    if print_tables:
        # Stampa l'array delle etichette Y
        print('-' * 50 + ' Y_TRAIN ' + '-' * 50)
        display(Y_train)

    # Restituisci la matrice delle features X_train e l'array delle etichette Y_train
    return X_train, Y_train

# %% [markdown]
# ## Caricamento Validation - BABELE

# %% [markdown]
# ### Validation - distanza Chebyshev

# %%
def carica_validation_chebyshev(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di validation
  data_folder = '/CSV_DATASET/Validation/'
  csv_filename = 'Validation_babele_chebyshev_random.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di validation dal file CSV
  df_validation = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_validation = df_validation.drop(columns=['target', 'video-frame'])

  # Stampa la matrice delle features X
  if print_tables:
    print('-' * 50 + ' X_VALIDATION ' + '-' * 50)
    display(X_validation)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_validation = df_validation[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_VALIDATION ' + '-' * 50)
    display(Y_validation)

  return X_validation, Y_validation

# %% [markdown]
# ### Validation - distanza Cityblock

# %%
def carica_validation_cityblock(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di validation
  data_folder = 'CSV_DATASET/Validation/'
  csv_filename = 'Validation_babele_cityblock_random6.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di validation dal file CSV
  df_validation = pd.read_csv(full_path)

  # Salvataggio colonna "video-frame" per usi futuri
  validation_save = df_validation[['video-frame']].copy()

  # Rimuovi le colonne "target" e "video-frame" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_validation = df_validation.drop(columns=['target', 'video-frame'])

  # Stampa la matrice delle features X
  if print_tables:
    print('-' * 50 + ' X_VALIDATION ' + '-' * 50)
    display(X_validation)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_validation = df_validation[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_VALIDATION ' + '-' * 50)
    display(Y_validation)

  return X_validation, Y_validation, validation_save

# %% [markdown]
# ### Validation - distanza Coseno

# %%
def carica_validation_coseno(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di validation
  data_folder = '/CSV_DATASET/Validation/'
  csv_filename = 'Validation_babele_cosine.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di validation dal file CSV
  df_validation = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_validation = df_validation.drop(columns=['target', 'video-frame'])

  # Stampa la matrice delle features X
  if print_tables:
    print('-' * 50 + ' X_VALIDATION ' + '-' * 50)
    display(X_validation)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_validation = df_validation[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_VALIDATION ' + '-' * 50)
    display(Y_validation)

  return X_validation, Y_validation

# %% [markdown]
# ### Validation - distanza Euclidea

# %%
def carica_validation_euclidea(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di validation
  data_folder = '/CSV_DATASET/Validation/'
  csv_filename = 'Validation_babele_euclidean.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di validation dal file CSV
  df_validation = pd.read_csv(full_path)

  # Rimuovi le colonne "target" e "video-frame" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_validation = df_validation.drop(columns=['target', 'video-frame'])

  # Stampa la matrice delle features X
  if print_tables:
    print('-' * 50 + ' X_VALIDATION ' + '-' * 50)
    display(X_validation)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_validation = df_validation[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_VALIDATION ' + '-' * 50)
    display(Y_validation)

  return X_validation, Y_validation

# %% [markdown]
# ### Validation - X vs Mondo

# %%
def carica_validation_XvsMondo(lingua, print_tables=False):

    lingua = lingua.lower() #Pretendo l'input in minuscolo..

    # Definisci il percorso e il nome del file del dataset di validation
    data_folder = '/CSV_DATASET/Validation/'
    csv_filename = f'Validation_babele_cityblock_{lingua}VsMondo.csv'
    full_path = path_principale + data_folder + csv_filename

    # Carica il dataset di validation dal file CSV
    df_validation = pd.read_csv(full_path)

     # Salvataggio colonna "video-frame" per usi futuri
    validation_save = df_validation[['video-frame']].copy()

    # Rimuovi le colonne "target" e "video-frame" dal dataset e assegna i dati rimanenti alla matrice delle features X
    X_validation = df_validation.drop(columns=['target', 'video-frame'])

    if print_tables:
        # Stampa la matrice delle features X
        print('-' * 50 + ' X_VALIDATION ' + '-' * 50)
        display(X_validation)

    # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
    Y_validation = df_validation[['target']]

    if print_tables:
        # Stampa l'array delle etichette Y
        print('-' * 50 + ' Y_VALIDATION ' + '-' * 50)
        display(Y_validation)

    return X_validation, Y_validation, validation_save

# %% [markdown]
# ## Caricamento Test BABELE

# %%
path_principale = '/content/drive/Shareddrives/Progetti FVAB 22 23 - VSR & BABELE/Gruppi/Gruppo 22/Progetto BABELE/'

# %% [markdown]
# ### Test - distanza Chebyshev

# %%
def carica_test_chebyshev(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di test
  data_folder = '/CSV_DATASET/Test/'
  csv_filename = 'Test_babele_chebyshev.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di test dal file CSV
  df_test = pd.read_csv(full_path)

  # Rimuovi la colonna "target" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_test = df_test.drop(columns=['target', 'video-frame'])

  if print_tables:
    # Stampa la matrice delle features X
    print('-' * 50 + ' X_TEST ' + '-' * 50)
    display(X_test)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_test = df_test[['target']]

  # Stampa l'array delle etichette Y
  print('-' * 50 + ' Y_TEST ' + '-' * 50)
  display(Y_test)

  return X_test, Y_test

# %% [markdown]
# ### Test - distanza Cityblock

# %%
def carica_test_cityblock(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di test
  data_folder = 'CSV_DATASET/Test/'
  csv_filename = 'Test_babele_cityblock_random6.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di test dal file CSV
  df_test = pd.read_csv(full_path)

  # Salvataggio colonna "video-frame" per usi futuri
  test_save = df_test[['video-frame']].copy()

  # Rimuovi la colonna "target" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_test = df_test.drop(columns=['target', 'video-frame'])

  if print_tables:
    # Stampa la matrice delle features X
    print('-' * 50 + ' X_TEST ' + '-' * 50)
    display(X_test)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_test = df_test[['target']]

  if print_tables:
    # Stampa l'array delle etichette Y
    print('-' * 50 + ' Y_TEST ' + '-' * 50)
    display(Y_test)

  return X_test, Y_test,test_save

# %% [markdown]
# ### Test - distanza Coseno

# %%
def carica_test_coseno(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di test
  data_folder = '/CSV_DATASET/Test/'
  csv_filename = 'Test_babele_cosine.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di test dal file CSV
  df_test = pd.read_csv(full_path)

  # Rimuovi la colonna "target" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_test = df_test.drop(columns=['target', 'video-frame'])

  if print_tables:
    # Stampa la matrice delle features X
    print('-' * 50 + ' X_TEST ' + '-' * 50)
    display(X_test)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_test = df_test[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_TEST ' + '-' * 50)
    display(Y_test)

  return X_test, Y_test

# %% [markdown]
# ### Test - distanza Euclidea

# %%
def carica_test_euclidea(print_tables=False):

  # Definisci il percorso e il nome del file del dataset di test
  data_folder = '/CSV_DATASET/Test/'
  csv_filename = 'Test_babele_euclidean.csv'
  full_path = path_principale + data_folder + csv_filename

  # Carica il dataset di test dal file CSV
  df_test = pd.read_csv(full_path)

  # Rimuovi la colonna "target" dal dataset e assegna i dati rimanenti alla matrice delle features X
  X_test = df_test.drop(columns=['target', 'video-frame'])

  if print_tables:
    # Stampa la matrice delle features X
    print('-' * 50 + ' X_TEST ' + '-' * 50)
    display(X_test)

  # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
  Y_test = df_test[['target']]

  # Stampa l'array delle etichette Y
  if print_tables:
    print('-' * 50 + ' Y_TEST ' + '-' * 50)
    display(Y_test)

  return X_test, Y_test

# %% [markdown]
# ### Test - X vs Mondo

# %%
def carica_test_XvsMondo(lingua, print_tables=False):

    lingua = lingua.lower() #Pretendo l'input in minuscolo..

    # Definisci il percorso e il nome del file CSV di test
    data_folder = '/CSV_DATASET/Test/'
    if lingua in ['francese', 'giapponese', 'inglese', 'tedesco', 'italiano', 'olandese', 'russo', 'spagnolo']:
        csv_filename = f'Test_babele_cityblock_{lingua}VsMondo.csv'
    else:
        raise ValueError("Lingua non valida. Hai inserito " + lingua)

    full_path = path_principale + data_folder + csv_filename

    # Leggi il file CSV e assegna i dati al dataframe df_test
    df_test = pd.read_csv(full_path)

     # Salvataggio colonna "video-frame" per usi futuri
    test_save = df_test[['video-frame']].copy()

    # Rimuovi le colonne "target" e "video-frame" dal dataframe e assegna i dati rimanenti alla matrice delle features X
    X_test = df_test.drop(columns=['target', 'video-frame'])

    if print_tables:
        # Stampa la matrice delle features X
        print('-' * 50 + ' X_TEST ' + '-' * 50)
        display(X_test)

    # Seleziona la colonna "target" e assegna i dati all'array delle etichette Y
    Y_test = df_test[['target']]

    if print_tables:
        # Stampa l'array delle etichette Y
        print('-' * 50 + ' Y_TEST ' + '-' * 50)
        display(Y_test)

    # Restituisci la matrice delle features X_test e l'array delle etichette Y_test
    return X_test, Y_test, test_save

# %% [markdown]
# # Funzioni di utilità per caricamento rapido dei vari dataset
# Attenzione: ricordare di eseguire le celle in alto che corrispondono al dataset da utilizzare

# %% [markdown]
# ## Caricamento dataset BABELE Train - Test

# %% [markdown]
# Carica il dataset di addestramento e di test ottenuto tramite le distanze e restituisce le feature e le etichette.
#
#
# Parametri:
# - distanza (String): distanza da eseguire.
# - logging (bool, opzionale): Se True, stampa un messaggio di log. Default: False.
#
# Return:
# - X_train (array-like): Feature del dataset di addestramento tramite la distanza considerata.
# - Y_train (array-like): Etichette del dataset di addestramento tramite la distanza considerata.
# - X_test (array-like): Feature del dataset di test ottenute tramite la distanza considerata.
# - Y_test (array-like): Etichette del dataset di test tramite la distanza considerata.
# - log (str): Messaggio di log che. Restituito solo se `logging` è True.

# %%
def carica_dataset_train_test(distanza="cityblock", logging=False):

    if "chebyshev" in distanza:
      X_train, Y_train = carica_train_chebyshev(print_tables=logging)
      X_test, Y_test, etichette_test = carica_test_chebyshev(print_tables=logging)
    elif "cosine" in distanza:
      X_train, Y_train = carica_train_coseno(print_tables=logging)
      X_test, Y_test, etichette_test = carica_test_coseno(print_tables=logging)
    elif "euclidea" in distanza:
      X_train, Y_train = carica_train_euclidea(print_tables=logging)
      X_test, Y_test, etichette_test = carica_test_euclidea(print_tables=logging)
    else:
      X_train, Y_train = carica_train_cityblock(print_tables=logging)
      X_test, Y_test, etichette_test = carica_test_cityblock(print_tables=logging)

    if logging:
        log = "Test"
        print("Sto caricando il dataset: " + log)

    return X_train, Y_train, X_test, Y_test, etichette_test

# %% [markdown]
# ## **Caricamento dataset BABELE Train-Validation**

# %% [markdown]
# Carica il dataset di addestramento e di validation ottenuto tramite le distanze e restituisce le feature e le etichette.
#
#
# Parametri:
# - distanza (String): distanza da eseguire. Se non è presente tra quelle disponibili, cityblok è la distanza di default (la migliore nel nostro caso di studio)
# - logging (bool, opzionale): Se True, stampa un messaggio di log. Default: False.
#
# Return:
# - X_train (array-like): Feature del dataset di addestramento ottenute tramite la distanza in questione.
# - Y_train (array-like): Etichette del dataset di addestramento.
# - X_validation (array-like): Feature del dataset di validation ottenute tramite la distanza in questione.
# - Y_validation (array-like): Etichette del dataset di validation ottenute tramite la distanza in questione.
# - log (str): Messaggio di log

# %%
def carica_dataset_train_validation(distanza="cityblock", logging=False):

    if "chebyshev" in distanza:
      X_train, Y_train = carica_train_chebyshev(print_tables=logging)
      X_validation, Y_validation, etichette_salvate = carica_validation_chebyshev(print_tables=logging)
    elif "cosine" in distanza:
      X_train, Y_train = carica_train_coseno(print_tables=logging)
      X_validation, Y_validation, etichette_salvate = carica_validation_coseno(print_tables=logging)
    elif "euclidea" in distanza:
      X_train, Y_train = carica_train_euclidea(print_tables=logging)
      X_validation, Y_validation, etichette_salvate = carica_validation_euclidea(print_tables=logging)
    else:
      X_train, Y_train = carica_train_cityblock(print_tables=logging)
      X_validation, Y_validation, etichette_salvate = carica_validation_cityblock(print_tables=logging)

    if logging:
        log = "Test"
        print("Sto caricando il dataset: " + log)

    return X_train, Y_train, X_validation, Y_validation, etichette_salvate

# %% [markdown]
# ## Caricamento dataset BABELE Train - Test XvsMondo
# *Confronto tra una lingua e il Mondo (tutte le lingue tranne quella considerata)*

# %% [markdown]
# Carica il dataset di addestramento e di test per la lingua specificata e restituisce le feature e le etichette.
# Parametri:
# - lingua (str): La lingua per cui caricare il dataset.
# - logging (bool, opzionale): Se True, stampa un messaggio di log. Default: False.
#
# Return:
# - X_train (array-like): Feature del dataset di addestramento.
# - Y_train (array-like): Etichette del dataset di addestramento.
# - X_test (array-like): Feature del dataset di test.
# - Y_test (array-like): Etichette del dataset di test.
# - log (str, opzionale): Messaggio di log contenente la lingua specificata (solo se logging=True).

# %%
def carica_dataset_train_test_XVsMondo(lingua, logging=False):
    X_train, Y_train = carica_train_XvsMondo(lingua)
    X_test, Y_test, test_save = carica_test_XvsMondo(lingua)

    if logging:
        log = "Test_"+lingua + "VsMondo"
        return X_train, Y_train, X_test, Y_test, test_save, log
    else:
        return X_train, Y_train, X_test, Y_test, test_save

# %% [markdown]
# ## Caricamento dataset BABELE Train - Validation XvsMondo
# *Confronto tra una lingua e il Mondo (tutte le lingue tranne quella considerata)*

# %% [markdown]
#  Carica il dataset di addestramento e di validation per la lingua
#  specificata e restituisce le feature e le etichette.
#  Confronto tra una lingua e il Mondo (tutte le lingue tranne quella considerata)
#
#
# Parametri:
# - lingua (str): La lingua per cui caricare il dataset.
# - logging (bool, opzionale): Se True, stampa un messaggio di log. Default: False.
#
# Return:
# - X_train (array-like): Feature del dataset di addestramento.
# - Y_train (array-like): Etichette del dataset di addestramento.
# - X_validation (array-like): Feature del dataset di validation.
# - Y_validation (array-like): Etichette del dataset di validation.
# - log (str, opzionale): Messaggio di log contenente la lingua specificata (solo se logging=True).

# %%
def carica_dataset_train_validation_XVsMondo(lingua, logging=False):

    X_train, Y_train = carica_train_XvsMondo(lingua, logging)  # Carica i dati di addestramento per la lingua corrente
    X_validation, Y_validation, etichette_salve = carica_validation_XvsMondo(lingua, logging)  # Carica i dati di convalida per la lingua corrente

    if logging:
        log = "Validation_" + lingua + "VsMondo"
        return X_train, Y_train, X_validation, Y_validation, etichette_salve, log
    else:
        return X_train, Y_train, X_validation, Y_validation, etichette_salve

# %% [markdown]
# #Implementazione di una Rete Neurale Probabilistica (PNN) per la classificazione con kernel e sigma variabili

# %% [markdown]
# ## **Definizione funzioni kernel per indicare l'intervallo della probabilità**

# %% [markdown]
# Generazione grafici delle funzioni del kernerl

# %%
def genera_grafico(function_name,function):
  # Generazione del range di valori di x
  x = np.linspace(-5, 5, 1000)

  # Calcolo dei valori della funzione uniform per ogni valore di x
  y = [function(i, 1) for i in x]

  # Creazione del grafico
  plt.plot(x, y)
  plt.title('Funzione '+ function_name)
  plt.xlabel('x')
  plt.ylabel('y')
  plt.show()

# %%
# Definizione di diverse funzioni kernel utilizzate nell'algoritmo di smoothing

# Uniform kernel
# La funzione restituisce 1/2 se l'argomento è compreso tra -b e b, altrimenti restituisce 0
uniform = lambda x,b: (np.abs(x/b) <= 1) and 1/2 or 0
genera_grafico("Uniform",uniform)

# Triangular kernel
# La funzione restituisce 1 - l'argomento normalizzato per b se l'argomento è compreso tra -b e b, altrimenti restituisce 0
triangle = lambda x,b: (np.abs(x/b) <= 1) and  (1 - np.abs(x/b)) or 0
genera_grafico("Triangle",triangle)

# Gaussian kernel
# La funzione restituisce il valore della distribuzione gaussiana centrata in 0 e con deviazione standard b valutata in x
gaussian = lambda x,b: (1.0/np.sqrt(2*np.pi))* np.exp(-.5*(x/b)**2)
genera_grafico("Gaussian",gaussian)

# Laplacian kernel
# La funzione restituisce il valore della distribuzione di Laplace centrata in 0 e con parametro di scala b valutata in x
laplacian = lambda x,b: (1.0/(2*b))* np.exp(-np.abs(x/b))
genera_grafico("Laplacian",laplacian)

# Epanechnikov kernel
# La funzione restituisce (3/4)*(1 - l'argomento normalizzato per b elevato al quadrato) se l'argomento è compreso tra -b e b, altrimenti restituisce 0
epanechnikov = lambda x,b: (np.abs(x/b)<=1) and ((3/4)*(1-(x/b)**2)) or 0
genera_grafico("Epanechnikov",epanechnikov)

# %% [markdown]
# ## **Creazione del livello Pattern**
# Il layer pattern utilizza una funzione kernel per valutare la distanza tra il punto
# di interesse e i punti dell'insieme di addestramento. I valori dei kernel sono utilizzati
# per ponderare i punti dell'insieme di addestramento in base alla loro vicinanza al punto di interesse.
#
# Tuttavia, i dati di addestramento possono contenere rumore o fluttuazioni casuali che possono
# influire negativamente sull'accuratezza del modello. Per ridurre l'effetto del rumore nei dati
# di addestramento, viene spesso utilizzata la tecnica di smoothing. In particolare, il parametro
# di smoothing sigma viene utilizzato per regolare l'effetto della distanza sui punti vicini e lontani dal punto di interesse, riducendo l'impatto
# del rumore e migliorando l'accuratezza del modello.

# %%
def pattern_layer(inp, kernel, sigma):
  # Inizializzazione di una lista per i valori dei kernel
  k_values = []

  # Iterazione su tutti i punti dell'insieme di addestramento
  for i, p in enumerate(X_train.values):
    # Calcolo della distanza euclidea tra il punto di addestramento e il punto di interesse
    edis = np.linalg.norm(p - inp)

    # Valutazione del kernel per la distanza euclidea calcolata e il parametro di smoothing sigma
    k = kernel(edis, sigma)

    # Aggiunta del valore del kernel alla lista
    k_values.append(k)

  # Restituzione della lista dei valori dei kernel
  return k_values

# %% [markdown]
# ## **Creazione del livello Summation**
# La funzione "summation_layer" prende in input una lista di valori del kernel "k_values",
# una serie di etichette di classe "Y_train" e un elenco delle diverse classi presenti nella
# serie di etichette di classe "class_counts". La funzione calcola la somma pesata dei valori
# di "k_values" per ogni classe nella serie di etichette di classe "Y_train" e restituisce una
# lista di valori medi ponderati per classe. In particolare, la funzione seleziona gli indici
# corrispondenti alla classe attuale e seleziona i valori di "k_values" corrispondenti alla classe attuale.
# La somma viene quindi divisa per il numero di campioni nella classe corrente,
# ottenuto utilizzando una funzione di Pandas, e il risultato viene normalizzato per ogni classe.
# Infine, la funzione restituisce la lista di valori medi ponderati per classe come output.

# %%
def summation_layer(k_values,Y_train,class_counts):
  # Determina il numero di classi diverse in Y_train
  num_classes = len(class_counts)
  # Inizializza un array di zeri con lunghezza uguale al numero di classi
  summed =[0] * num_classes

  # Calcola la somma pesata dei valori di k_values per ogni classe in Y_train
  for i,c in enumerate(class_counts):
    # Seleziona gli indici corrispondenti alla classe attuale
    val = (Y_train['target']==class_counts.index[i]).values;

    # Seleziona i valori di k_values corrispondenti alla classe attuale
    k_values = np.array(k_values);
    summed[i] = np.sum(k_values[val]);

  # Calcola la media ponderata dei valori per ogni classe
  avg_sum = list(summed/Y_train.value_counts());

  # Restituisce la lista di valori medi ponderati per classe
  return avg_sum

# %% [markdown]
# ## **Creazione del livello di Output**
# La funzione "output_layer" prende in input una lista di valori medi ponderati per classe "avg_sum"
# e un elenco delle diverse classi presenti nella serie di etichette di classe "class_counts".
# La funzione restituisce l'etichetta di classe corrispondente all'indice dell'elemento massimo nella lista
# delle medie delle somme dei valori di "k_values" per ogni classe. In particolare, la funzione determina il
# valore massimo nella lista delle medie delle somme dei valori di "k_values" per ogni classe, quindi determina
# l'indice dell'elemento massimo nella lista e infine determina l'etichetta di classe corrispondente all'indice
# dell'elemento massimo nella lista delle medie delle somme dei valori di "k_values" per ogni classe.
# Infine, la funzione restituisce l'etichetta di classe come una stringa come output.

# %%
def output_layer(avg_sum, class_counts):
  # Determina il valore massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  max_value = max(avg_sum)

  # Determina l'indice dell'elemento massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  max_index = avg_sum.index(max_value)

  # Determina l'etichetta di classe corrispondente all'indice dell'elemento massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  label = class_counts.index[max_index][0]

  # Restituisce l'etichetta di classe come una stringa
  return label

# %% [markdown]
# ## **Unione dei tre livelli della Probabilistic Neural Network**
# La funzione pnn implementa un classificatore denominato "Probabilistic Neural Network" (PNN) per la classificazione
# di un set di dati X_test sulla base di un set di dati di training X_train con le relative etichette di classe Y_train.
# Viene calcolata una stima della densità di probabilità per ogni classe presente in Y_train utilizzando
# una funzione kernel (specificata come parametro) e una larghezza di banda sigma (anche questo come parametro).
# Successivamente, per ogni osservazione in X_test, la funzione utilizza le stime di densità di probabilità
# per calcolare la probabilità che l'osservazione appartenga a ciascuna classe presente in Y_train.
# Infine, l'etichetta di classe con la probabilità più alta viene assegnata all'osservazione e viene aggiunta
# alla lista di etichette di classe generate.
# La funzione restituisce la lista di etichette di classe generate e stampa un messaggio di conferma.

# %%
def pnn(X_train,Y_train,X_test,kernel,sigma):
  # Determina il conteggio di ogni classe nella serie di etichette di classe Y_train
  class_counts = Y_train.value_counts()

  # Inizializza una lista vuota per le etichette di classe generate
  labels=[]

  # Iterazione su ogni osservazione del set di test
  for s in X_test.values:
    # Calcola i valori del kernel per l'osservazione attuale
    k_values = pattern_layer(s,kernel,sigma);

    # Calcola la somma pesata dei valori del kernel per ogni classe presente nella serie di etichette di classe Y_train
    avg_sum = summation_layer(k_values,Y_train,class_counts);

    # Determina l'etichetta di classe corrispondente all'osservazione attuale
    label = output_layer(avg_sum,class_counts);

    # Aggiunge l'etichetta di classe alla lista delle etichette di classe generate
    labels.append(label);

  # Restituisce la lista delle etichette di classe generate
  return labels;

# %% [markdown]
# ## PNN compattata per un utilizzo più rapido
# Per caricare la PNN interamente senza troppi passaggi eseguira la cella in questione

# %%
# Uniform kernel
uniform = lambda x,b: (np.abs(x/b) <= 1) and 1/2 or 0

# Triangular kernel
triangle = lambda x,b: (np.abs(x/b) <= 1) and  (1 - np.abs(x/b)) or 0

# Gaussian kernel
gaussian = lambda x,b: (1.0/np.sqrt(2*np.pi))* np.exp(-.5*(x/b)**2)

# Laplacian kernel
laplacian = lambda x,b: (1.0/(2*b))* np.exp(-np.abs(x/b))

# Epanechnikov kernel
epanechnikov = lambda x,b: (np.abs(x/b)<=1) and ((3/4)*(1-(x/b)**2)) or 0

def pattern_layer(inp, kernel, sigma):
  # Inizializzazione di una lista per i valori dei kernel
  k_values = []

  # Iterazione su tutti i punti dell'insieme di addestramento
  for i, p in enumerate(X_train.values):
    # Calcolo della distanza euclidea tra il punto di addestramento e il punto di interesse
    edis = np.linalg.norm(p - inp)

    # Valutazione del kernel per la distanza euclidea calcolata e il parametro di smoothing sigma
    k = kernel(edis, sigma)

    # Aggiunta del valore del kernel alla lista
    k_values.append(k)

  # Restituzione della lista dei valori dei kernel
  return k_values

def summation_layer(k_values,Y_train,class_counts):
  # Determina il numero di classi diverse in Y_train
  num_classes = len(class_counts)
  # Inizializza un array di zeri con lunghezza uguale al numero di classi
  summed =[0] * num_classes

  # Calcola la somma pesata dei valori di k_values per ogni classe in Y_train
  for i,c in enumerate(class_counts):
    # Seleziona gli indici corrispondenti alla classe attuale
    val = (Y_train['target']==class_counts.index[i]).values;

    # Seleziona i valori di k_values corrispondenti alla classe attuale
    k_values = np.array(k_values);
    summed[i] = np.sum(k_values[val]);

  # Calcola la media ponderata dei valori per ogni classe
  avg_sum = list(summed/Y_train.value_counts());

  # Restituisce la lista di valori medi ponderati per classe
  return avg_sum

def output_layer(avg_sum, class_counts):
  # Determina il valore massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  max_value = max(avg_sum)

  # Determina l'indice dell'elemento massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  max_index = avg_sum.index(max_value)

  # Determina l'etichetta di classe corrispondente all'indice dell'elemento massimo nella lista delle medie delle somme dei valori di k_values per ogni classe
  label = class_counts.index[max_index][0]

  # Restituisce l'etichetta di classe come una stringa
  return label

def pnn(X_train,Y_train,X_test,kernel,sigma):
  # Determina il conteggio di ogni classe nella serie di etichette di classe Y_train
  class_counts = Y_train.value_counts()

  # Inizializza una lista vuota per le etichette di classe generate
  labels=[]

  # Iterazione su ogni osservazione del set di test
  for s in X_test.values:
    # Calcola i valori del kernel per l'osservazione attuale
    k_values = pattern_layer(s,kernel,sigma);

    # Calcola la somma pesata dei valori del kernel per ogni classe presente nella serie di etichette di classe Y_train
    avg_sum = summation_layer(k_values,Y_train,class_counts);

    # Determina l'etichetta di classe corrispondente all'osservazione attuale
    label = output_layer(avg_sum,class_counts);

    # Aggiunge l'etichetta di classe alla lista delle etichette di classe generate
    labels.append(label);

  # Restituisce la lista delle etichette di classe generate
  return labels;

# %% [markdown]
# # Applicazione Particle Swarm Optimization per ricerca parametri ottimi
# In questa sezione si utilizza l'algoritmo PSO(Particle Swarm Optimization) per l'ottimizzazione dei parametri di una PNN, in modo da trovare i valori ottimali di sigma e del kernel che massimizzino la sua capacità di generalizzazione sui dati di test. L'algoritmo PSO utilizza una funzione obiettivo per valutare la qualità delle soluzioni candidate e cerca di trovare i valori ottimali dei parametri muovendo le particelle verso le soluzioni migliori. Alla fine dell'ottimizzazione, il notebook restituisce i valori di sigma e del kernel ottimali, insieme alla metrica di performance, che possono essere utilizzati per addestrare e testare la PNN con i dati di addestramento e di test.

# %% [markdown]
# In particolare i parametri usati sono i seguenti:
#
# *   options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}: questi sono i parametri dell'algoritmo PSO. In particolare, 'c1' e 'c2' rappresentano i coefficienti di accelerazione cognitiva e sociale, rispettivamente, mentre 'w' rappresenta il peso dell'inerzia. Questi parametri controllano la velocità con cui le particelle si muovono verso la migliore soluzione individuale e globale, nonché l'effetto dell'inerzia sulla loro velocità.
# *   bounds = ([0.1], [1.8]): questi sono i limiti inferiori e superiori per il valore di sigma, il parametro che stiamo cercando di ottimizzare. In particolare, abbiamo impostato il limite inferiore a 0.1 e il limite superiore a 1.8, poiché sappiamo che il valore ottimale di sigma si trova in questo intervallo.
#
# *   n_particles = 30: questo parametro indica il numero di particelle utilizzate nell'algoritmo PSO. Un numero più elevato di particelle può aumentare la precisione dell'ottimizzazione, ma richiede anchepiù tempo di esecuzione.
#
# *   n_iterations = 100: questo parametro indica il numero di iterazioni dell'algoritmo PSO. Più iterazioni possono migliorare la precisione dell'ottimizzazione, ma richiedono anche più tempo di esecuzione. Abbiamo scelto 100 iterazioni poiché abbiamo verificato che questo valore è sufficiente per raggiungere la convergenza dell'algoritmo.

# %%
# !pip install pyswarms
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Applicazione PSO su Train-Test BABELE

# %%
import pyswarms as ps

X_train, Y_train, X_test, Y_test, etichette_test = carica_dataset_train_test()

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_test, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_test, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Imposta i parametri per l'algoritmo PSO
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
n_particles = 45
n_iterations = 100

# Esegui l'ottimizzazione
optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

# Ottieni il valore ottimo di sigma
sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

# Stampa il valore ottimo di sigma
print("Sigma Ottimo:", sigma_opt)


# verifica se la cartella di destinazione esiste, altrimenti la crea
if not os.path.exists(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/'):
    os.makedirs(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/')

# Salvataggio del valore ottimo di sigma in un file CSV
df_sigma = pd.DataFrame({'Sigma Ottimo': [sigma_opt]})
df_sigma.to_csv(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/'+ 'train-test_sigma_ottimo_frame_random.csv', index=False)
# Out:
# 2023-06-12 10:38:52,494 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.287
# 2023-06-12 10:45:23,036 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.2875, best pos: [1.1818768]
# Sigma Ottimo: 1.1818767956152745

# %% [markdown]
# ### **Applicazione PSO su Train-Validation BABELE**

# %%
import pyswarms as ps
import pandas as pd

# X_train, Y_train, X_test, Y_test = carica_dataset_train_test_of_sequenza()
X_train, Y_train, X_validation, Y_validation, etichette_test = carica_dataset_train_validation()

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_validation, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_validation, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Imposta i parametri per l'algoritmo PSO
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
n_particles = 45
n_iterations = 100

# Esegui l'ottimizzazione
optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

# Ottieni il valore ottimo di sigma
sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

# Stampa il valore ottimo di sigma
print("Sigma Ottimo:", sigma_opt)


path_destinazione = path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/'

# verifica se la cartella di destinazione esiste, altrimenti la crea
if not os.path.exists(path_destinazione):
    os.makedirs(path_destinazione)

# Salvataggio del valore ottimo di sigma in un file CSV
df_sigma = pd.DataFrame({'Sigma Ottimo': [sigma_opt]})
df_sigma.to_csv(path_destinazione + 'train-validation_sigma_ottimo.csv', index=False)

# %% [markdown]
# ### Applicazione PSO su Train-Test - XvsMondo BABELE

# %%
import pyswarms as ps
import pandas as pd

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_test, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_test, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Definisci la lista di lingue
lingue = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']

# Dizionario per salvare i valori ottimi di sigma per ogni lingua
ottimi_sigma = {}

# Itera su ogni lingua per calcolare il valore ottimo di sigma
for lingua in lingue:
    X_train, Y_train, X_test, Y_test , test_save= carica_dataset_train_test_XVsMondo(lingua, logging=False)

    # Imposta i parametri per l'algoritmo PSO
    options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
    bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
    n_particles = 45
    n_iterations = 100

    # Esegui l'ottimizzazione
    optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
    best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

    # Ottieni la massima accuratezza e sigma ottimizzato
    accuracy_max = -best_cost
    sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

    # Salva il valore ottimo di sigma nel dizionario
    ottimi_sigma[lingua] = sigma_opt

    # Stampa la massima accuratezza e sigma ottimizzato per la lingua corrente
    print("Lingua:", lingua)
    print("Massima Accuratezza:", accuracy_max)
    print("Sigma Ottimizzato:", sigma_opt)
    print("---" * 50)

# Stampa il dizionario dei valori ottimi di sigma
print("Valori Ottimi di Sigma per ogni Lingua:")
print(ottimi_sigma)


path_destinazione = path_principale + '/Codici PNN/Sigma ottimi/BABELE/XvsMondo/'

# verifica se la cartella di destinazione esiste, altrimenti la crea
if not os.path.exists(path_destinazione):
    os.makedirs(path_destinazione)

# Converti il dizionario in un DataFrame
df_sigma = pd.DataFrame(list(ottimi_sigma.items()), columns=['Lingua', 'Sigma Ottimo'])

# Salvataggio del DataFrame in un file CSV
df_sigma.to_csv(path_destinazione+ 'train-test_sigma_ottimiXvsMondo.csv', index=False)
# Out:
# 2023-06-12 08:53:09,052 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.525
# 2023-06-12 08:53:45,296 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.525, best pos: [0.84729387]
# Lingua: Italiano
# Massima Accuratezza: 0.525
# Sigma Ottimizzato: 0.8472938719938448
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2023-06-12 08:53:45,968 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.8
# 2023-06-12 08:54:16,839 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.8, best pos: [0.12865651]
# Lingua: Inglese
# Massima Accuratezza: 0.8
# Sigma Ottimizzato: 0.12865651433442227
# ...

# %% [markdown]
# ### Applicazione PSO su Train-Validation BABELE XvsMondo

# %%
import pyswarms as ps
import pandas as pd

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_validation, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_validation, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Definisci la lista di lingue
lingue = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']

# Dizionario per salvare i valori ottimi di sigma per ogni lingua
ottimi_sigma = {}

# Itera su ogni lingua per calcolare il valore ottimo di sigma
for lingua in lingue:
    X_train, Y_train, X_validation, Y_validation = carica_dataset_train_validation_XVsMondo(lingua, logging=False)

    # Imposta i parametri per l'algoritmo PSO
    options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
    bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
    n_particles = 45
    n_iterations = 100

    # Esegui l'ottimizzazione
    optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
    best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

    # Ottieni la massima accuratezza e sigma ottimizzato
    accuracy_max = -best_cost
    sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

    # Salva il valore ottimo di sigma nel dizionario
    ottimi_sigma[lingua] = sigma_opt

    # Stampa la massima accuratezza e sigma ottimizzato per la lingua corrente
    print("Lingua:", lingua)
    print("Massima Accuratezza:", accuracy_max)
    print("Sigma Ottimizzato:", sigma_opt)
    print("---" * 50)

# Stampa il dizionario dei valori ottimi di sigma
print("Valori Ottimi di Sigma per ogni Lingua:")
print(ottimi_sigma)


path_destinazione = path_principale + '/Codici PNN/Sigma ottimi/BABELE/XvsMondo/'

# verifica se la cartella di destinazione esiste, altrimenti la crea
if not os.path.exists(path_destinazione):
    os.makedirs(path_destinazione)

# Converti il dizionario in un DataFrame
df_sigma = pd.DataFrame(list(ottimi_sigma.items()), columns=['Lingua', 'Sigma Ottimo'])

# Salvataggio del DataFrame in un file CSV
df_sigma.to_csv(path_destinazione + 'train-validation_sigma_ottimiXvsMondo.csv', index=False)
# Out:
# 2023-06-01 13:02:01,863 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.725
# 2023-06-01 13:02:27,912 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.725, best pos: [0.2302317]
# Lingua: Italiano
# Massima Accuratezza: 0.725
# Sigma Ottimizzato: 0.23023169997382248
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2023-06-01 13:02:28,302 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.55
# 2023-06-01 13:02:54,327 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.55, best pos: [1.37127725]
# Lingua: Inglese
# Massima Accuratezza: 0.55
# Sigma Ottimizzato: 1.3712772530515531
# ...

# %% [markdown]
# # Applicazione PNN su dataset BABELE

# %% [markdown]
# ## Funzioni di utilità da eseguire

# %% [markdown]
# ### Funzione Trova Video con predizione errata

# %% [markdown]
# La funzione *trova_video_pred_errati_global* ha lo scopo di individuare e visualizzare le previsioni errate a livello globale, confrontando le etichette vere (y_test) con le previsioni (predict) per ogni video nel DataFrame etichette_test. Inoltre, offre la possibilità di salvare i risultati in un file CSV, se specificati il percorso di salvataggio e il nome del file.
#
# Parametri della funzione:
#
# - etichette_test: DataFrame contenente le informazioni sui video, inclusi i nomi dei video e le etichette vere.
# - y_test: Serie o DataFrame con le etichette vere dei video.
# -predict: Serie o DataFrame con le previsioni dei video.
# - save_path (opzionale): Percorso di salvataggio per il file CSV contenente i risultati. Se non specificato, il file non viene salvato.
# - nomefile (opzionale): Nome del file CSV contenente i risultati. Se non specificato, il file non viene salvato.
#
# Ad esempio, se il modello mostra una percentuale significativa di previsioni errate globali, potrebbe essere necessario esaminare attentamente le caratteristiche dei video che causano confusione al modello

# %%
def trova_video_pred_errati_global(etichette_test, y_test, predict, save_path=None, nomefile=None):
    # Creazione del DataFrame con le informazioni dei video, le etichette vere e le previsioni
    df = pd.DataFrame({
        'Nome Video': etichette_test['video-frame'],
        'True Label': y_test['target'],
        'Predicted Label': predict
    })

    # Creazione di un nuovo DataFrame con le righe in cui le etichette vere e le previsioni sono diverse
    df_diff = df[df['True Label'] != df['Predicted Label']]

    # Stampa del DataFrame con le previsioni errate globali
    print('-' * 50 + f' DATAFRAME PREDIZIONI ERRATE GLOBAL ' + '-' * 50)
    display(df_diff)

    # Salvataggio del DataFrame in formato CSV, se specificato il percorso di salvataggio e il nome del file
    if save_path is not None and nomefile is not None:
        os.makedirs(save_path, exist_ok=True)
        df_diff.to_csv(os.path.join(save_path, nomefile + '.csv'), index=False)

# %% [markdown]
# La funzione *trova_video_pred_errati_lingua* è utilizzata per individuare i video specifici in cui il modello fa previsioni errate per una determinata classe di predizione.
#
# I parametri della funzione trova_video_pred_errati_lingua sono i seguenti:
#
# - etichette_test: È il DataFrame delle etichette di test, che contiene le informazioni sui video utilizzati per il test del modello.
# - y_test: Sono le etichette vere di test, che rappresentano le classi corrette dei video.
# - predict: Sono le previsioni del modello, che rappresentano le classi predette per i video.
# - pred_value (opzionale): È il valore di predizione specifico per cui si desidera individuare i video con previsioni errate. Di default, il valore è impostato a 3.
# - save_path (opzionale): È il percorso di salvataggio in cui si desidera salvare il DataFrame con le informazioni dei video con previsioni errate. Se non specificato, il DataFrame non verrà salvato.
# - nomefile (opzionale): È il nome del file per il salvataggio del DataFrame con le informazioni dei video con previsioni errate. Questo parametro è utilizzato solo se save_path è specificato.
#
# Ad esempio, se il modello mostra una percentuale significativa sul Tedesco di previsioni errate globali, potrebbe essere necessario esaminare attentamente le caratteristiche dei video che causano confusione al modello

# %%
def trova_video_pred_errati_lingua(etichette_test, y_test, predict, pred_value=3, save_path=None, nomefile=None):
    # Creazione del DataFrame con le informazioni dei video, le etichette vere e le previsioni
    df = pd.DataFrame({
        'Nome Video': etichette_test['video-frame'],
        'True Label': y_test['target'],
        'Predicted Label': predict
    })

    # Creazione di un nuovo DataFrame con le righe in cui le etichette vere e le previsioni sono diverse
    df_diff = df[df['True Label'] != df['Predicted Label']]

    # Creazione di un nuovo DataFrame con le righe in cui la previsione è uguale a pred_value
    df_pred_val = df_diff.loc[df_diff['Predicted Label'] == pred_value]

    # Stampa del DataFrame con le previsioni errate per il target specificato (pred_value)
    print('-' * 50 + f' DATAFRAME PREDIZIONI ERRATE PER TARGET ({pred_value}) ' + '-' * 50)
    display(df_pred_val)

    # Salvataggio del DataFrame in formato CSV, se specificato il percorso di salvataggio e il nome del file
    if save_path is not None and nomefile is not None:
        os.makedirs(save_path, exist_ok=True)
        df_pred_val.to_csv(os.path.join(save_path, nomefile + '.csv'), index=False)

# %% [markdown]
# ### Funzione per la creazione (+ salvataggio) della matrice di confusione
#
# La funzione *create_confusion_matrix* è utilizzata per creare e visualizzare una matrice di confusione a partire dalle etichette vere (Y_test) e le previsioni (pred) ottenute dal modello.
#
# Parametri:
#
# - Y_test: DataFrame o array contenente le etichette vere.
# pred: DataFrame o array contenente le previsioni del modello.
# - labels: Lista delle etichette di classe.
# sigma: Valore del parametro di smoothing utilizzato nel modello.
# - kernel: Tipo di kernel utilizzato nel modello.
# - save_path (opzionale): Percorso della cartella in cui salvare l'immagine della matrice di confusione.
# - filename (opzionale): Nome del file dell'immagine della matrice di confusione.

# %%
def create_confusion_matrix(Y_test, pred, labels, sigma, kernel, save_path=None, filename=None):
  cm = confusion_matrix(Y_test.values, pred)

  # Plot della matrice di confusione
  plt.figure(figsize=(8, 6))
  sns.heatmap(cm, annot=True, cmap='Reds', xticklabels=labels, yticklabels=labels, vmin=0, vmax=20)
  plt.xlabel('Predicted label')
  plt.ylabel('True label')
  plt.title('Matrice di confusione (sigma='+str(sigma)+' , kernel='+kernel+')')

# Salvataggio dell'immagine della matrice di confusione
  if save_path is not None:

      # Definizione della cartella di destinazione per le immagini delle matrici di confusione
      os.makedirs(save_path, exist_ok=True)

      if filename is not None:
       plt.savefig(save_path + filename+'.png', bbox_inches='tight')

      else:
        plt.savefig(save_path + "ConfusionMatrix.png", bbox_inches='tight')
      plt.show()
  else:
      plt.show()

  plt.close()

# %% [markdown]
# ## Distanze

# %% [markdown]
# #### Applicazione su Train-Test BABELE - distanze

# %%
# Carica il DataFrame del sigma ottimo utilizzando il kernel gaussiano
df_sigmaOttimo = pd.read_csv(path_principale + 'Codici PNN/Sigma ottimi/BABELE/Distanze/train-test_sigma_ottimo_frame_random.csv')
sigmaOttimo = df_sigmaOttimo['Sigma Ottimo'][0]

# Si utilizza il kernel Gaussiano
k_func = gaussian

# Caricamento del dataset
X_train, Y_train, X_test, Y_test, etichette_test = carica_dataset_train_test()

# Generazione delle etichette di classe per il set di test utilizzando il kernel corrente e il valore di sigma corrente
pred = pnn(X_train, Y_train, X_test, k_func, sigmaOttimo)

# Valutazione delle metriche di performance
accuracy = accuracy_score(Y_test, pred)
accuracy_100 = "{:.2%}".format(accuracy)
f1 = "{:.2%}".format(f1_score(Y_test, pred, average='weighted'))
precision = "{:.2%}".format(precision_score(Y_test, pred, average='micro'))
recall_score = "{:.2%}".format(recall_score(Y_test, pred, average='micro'))

# Inizializzazione di un DataFrame vuoto per salvare le statistiche di performance
results = pd.DataFrame(columns=['Kernel', 'Smoothing Param', 'Accuracy', 'Accuracy (%)', 'F1-Score', 'Precision', 'Recall'])

# Aggiunta delle statistiche di performance per la combinazione corrente di kernel e sigma al DataFrame results
results.loc[len(results)] = ["Gaussian", sigmaOttimo, accuracy, accuracy_100, f1, precision, recall_score]

# Stampa del DataFrame results. Per una questione di stile, elimino la colonna 'Accuracy' in quanto è presente 'Accuracy (%)'
print(results.drop(columns=['Accuracy']))
print("---" * 100)

# Creazione della matrice di confusione
lingue = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']

nomefile_matrix = 'CM_train-test_A' + format(accuracy, '.3f')
output_folder_matrix = path_principale + '/Codici PNN/Matrici Confusione/BABELE/Distanze/'
create_confusion_matrix(Y_test, pred, lingue, sigmaOttimo, "Gaussian", save_path=output_folder_matrix, filename=nomefile_matrix)

# Trova i video con previsioni errate globalmente
output_folder_video_pred_err = path_principale + '/Codici PNN/Previsioni Errate/BABELE/Distanze/Test'
nomefile_pred_errate = 'train-test_video_pred_errate_global'
trova_video_pred_errati_global(etichette_test, Y_test, pred, output_folder_video_pred_err, nomefile_pred_errate)

# Trova i video con previsioni errate per ogni lingua
for lingua in lingue:
    nomefile_pred_errate_lingua = f'train-test_video_pred_errate_{lingua}'
    trova_video_pred_errati_lingua(etichette_test, Y_test, pred, lingue.index(lingua) + 1, output_folder_video_pred_err, nomefile_pred_errate_lingua)

'''
nome_file_csv = 'cityblock_frame_random.csv'
csv_path = "/content/drive/Shareddrives/Progetti FVAB 22 23 - VSR & BABELE/Gruppi/Gruppo 22/Progetto BABELE/CSV_PNN_RESULT/"+nome_file_csv
results.to_csv(csv_path, index=False) #Creazione csv da dataframe su dati di test'''
# Out:
#      Kernel  Smoothing Param Accuracy (%) F1-Score Precision  Recall
# 0  Gaussian         1.181877       31.87%   25.38%    31.87%  31.87%
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#         Nome Video  True Label  Predicted Label
# 0    1_1_1_14_30_1           1                5
# 1    1_1_1_14_30_2           1                5
# 2    1_1_1_14_30_3           1                5
# 3    1_1_1_14_30_4           1                5
# 4    1_1_1_14_30_5           1                5
# ..             ...         ...              ...
# 155   8_2_1_3_25_5           8                6
# 156   8_2_1_3_25_3           8                6
# 157   8_2_1_3_25_4           8                6
# 158   8_2_1_3_25_2           8                6
# ...

# %%
import pyswarms as ps

X_train, Y_train, X_test, Y_test, etichette_test = carica_dataset_train_test()

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_test, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_test, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Imposta i parametri per l'algoritmo PSO
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
n_particles = 45
n_iterations = 100

# Esegui l'ottimizzazione
optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

# Ottieni il valore ottimo di sigma
sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

# Stampa il valore ottimo di sigma
print("Sigma Ottimo:", sigma_opt)


# verifica se la cartella di destinazione esiste, altrimenti la crea
if not os.path.exists(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/'):
    os.makedirs(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/')

# Salvataggio del valore ottimo di sigma in un file CSV
df_sigma = pd.DataFrame({'Sigma Ottimo': [sigma_opt]})
df_sigma.to_csv(path_principale + '/Codici PNN/Sigma ottimi/BABELE/Distanze/'+ 'train-test_sigma_ottimo_6frame_random.csv', index=False)
# Out:
# 2023-06-12 10:28:09,511 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=-.325
# 2023-06-12 10:34:51,718 - pyswarms.single.global_best - INFO - Optimization finished | best cost: -0.325, best pos: [1.60311524]
# Sigma Ottimo: 1.6031152446507695

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel'], marker='o');
plt.title('Accuracy for Different Kernels on Valid. set',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel'], marker='s');
plt.title('F1-Score for Different Kernels on Valid. set',loc='left');

plt.show()

# %% [markdown]
# #### Applicazione su Train-Validation BABELE - distanze

# %%
# Carica il DataFrame dei sigma ottimi utilizzando il kernel gaussiano
df_sigmaOttimo = pd.read_csv(path_principale + 'Codici PNN/Sigma ottimi/BABELE/Distanze/train-validation_sigma_ottimo.csv')
sigmaOttimo = df_sigmaOttimo['Sigma Ottimo'][0]

# Si utilizza il kernel Gaussiano
k_func = gaussian

# Caricamento del dataset
X_train, Y_train, X_validation, Y_validation, etichette_validation = carica_dataset_train_validation()

# Generazione delle etichette di classe per il set di validazione utilizzando il kernel corrente e il valore di sigma corrente
pred = pnn(X_train, Y_train, X_validation, k_func, sigmaOttimo)

# Valutazione delle metriche di performance
accuracy = accuracy_score(Y_validation, pred)
accuracy_100 = "{:.2%}".format(accuracy)
f1 = "{:.2%}".format(f1_score(Y_validation, pred, average='weighted'))
precision = "{:.2%}".format(precision_score(Y_validation, pred, average='micro'))
#recall = "{:.2%}".format(recall_score(Y_validation, pred, average='micro'))

# Inizializzazione di un DataFrame vuoto per salvare le statistiche di performance
results = pd.DataFrame(columns=['Kernel', 'Smoothing Param', 'Accuracy', 'Accuracy (%)', 'F1-Score', 'Precision', 'Recall'])

# Aggiunta delle statistiche di performance per la combinazione corrente di kernel e sigma al DataFrame results
results.loc[len(results)] = ["Gaussian", sigmaOttimo, accuracy, accuracy_100, f1, precision, 0]

# Stampa del DataFrame results. Per una questione di stile, elimino la colonna 'Accuracy' in quanto è presente 'Accuracy (%)'
print(results.drop(columns=['Accuracy']))
print("---" * 100)

# Creazione della matrice di confusione
labels = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']
nomefile_matrix = 'CM_train-validation_A' + format(accuracy, '.3f')
outputfolder_matrix = path_principale + '/Codici PNN/Matrici Confusione/BABELE/Distanze/'
create_confusion_matrix(Y_validation, pred, labels, sigmaOttimo, "Gaussian", save_path=outputfolder_matrix, filename=nomefile_matrix)

# Trova i video con previsioni errate a livello globale
output_folder_video_pred_err = path_principale + '/Codici PNN/Previsioni Errate/BABELE/Distanze/Validation'
nomefile_pred_errate = 'train-validation_video_pred_errate_global'
trova_video_pred_errati_global(etichette_validation, Y_validation, pred, output_folder_video_pred_err, nomefile_pred_errate)

# Trova i video con previsioni errate per ogni lingua
for lingua in lingue:
    nomefile_pred_errate_lingua = f'train-validation_video_pred_errate_{lingua}'
    trova_video_pred_errati_lingua(etichette_validation, Y_validation, pred, lingue.index(lingua) + 1, output_folder_video_pred_err, nomefile_pred_errate_lingua)
# Out:
#      Kernel  Smoothing Param Accuracy (%) F1-Score Precision  Recall
# 0  Gaussian         0.330867       29.38%   21.75%    29.38%       0
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------- DATAFRAME PREDIZIONI ERRATE GLOBAL--------------------------------------------------
#         Nome Video  True Label  Predicted Label
# 0    2_1_1_11_25_1           2                1
# 1    2_1_1_11_25_2           2                6
# 2    2_1_1_11_25_3           2                6
# 3    2_1_1_11_25_4           2                6
# 4    2_1_1_11_25_5           2                6
# ..             ...         ...              ...
# 153   8_1_2_2_30_2           8                6
# ...

# %%
import pyswarms as ps
import pandas as pd

X_train, Y_train, X_test, Y_test = carica_dataset_train_test()

# Definisci la funzione obiettivo per l'ottimizzazione
def pnn_accuracy_score(x):
    kernel = gaussian  # Utilizza il kernel gaussiano
    preds = pnn(X_train, Y_train, X_test, kernel, x[0])  # Utilizza x[0] come valore di sigma
    return -accuracy_score(Y_test, preds)  # Negare il punteggio di accuratezza per la massimizzazione

# Imposta i parametri per l'algoritmo PSO
options = {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
bounds = ([0.1], [1.8])  # Imposta i limiti inferiori e superiori per sigma
n_particles = 30
n_iterations = 100

# Esegui l'ottimizzazione
optimizer = ps.single.GlobalBestPSO(n_particles=n_particles, dimensions=1, options=options, bounds=bounds)
best_cost, best_pos = optimizer.optimize(pnn_accuracy_score, n_iterations)

# Ottieni la massima accuratezza e sigma ottimizzato
accuracy_max = -best_cost
sigma_opt = best_pos[0]  # Estrai sigma ottimizzato dall'array della migliore posizione

# Stampa la massima accuratezza e sigma ottimizzato
print("Massima Accuratezza:", accuracy_max)
print("Sigma Ottimizzato:", sigma_opt)

# %% [markdown]
# #### Applicazione su Test - X vs Mondo BABELE

# %%
# Caricamento del DataFrame dei sigma ottimi
sigmaOttimi = pd.read_csv(path_principale + '/Codici PNN/Sigma ottimi/BABELE/XvsMondo/' + 'train-test_sigma_ottimiXvsMondo.csv')

# Definizione della lista di lingue disponibili da confrontare con Mondo
lingue = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']

# Inizializzazione di un DataFrame vuoto per salvare le statistiche di performance del classificatore
results = pd.DataFrame(columns=['Kernel', 'Smoothing Param', 'Lingua', 'Accuracy', 'Accuracy (%)', 'F1-Score', 'Precision', 'Recall'])
output_folder_video_pred_err = path_principale + '/Codici PNN/Previsioni Errate/BABELE/Distanze/XvsMondo/Test'

# Iterazione su ogni lingua
for lingua in lingue:

    print("---" * 100)

    # Ottieni il sigma ottimo corrispondente alla lingua corrente dal DataFrame sigmaOttimi
    sigma_opt = sigmaOttimi.loc[sigmaOttimi['Lingua'] == lingua, 'Sigma Ottimo'].values[0]

    # Caricamento dei dati per la lingua corrente
    X_train, Y_train, X_test, Y_test, etichette_salvate = carica_dataset_train_test_XVsMondo(lingua, logging=False)

    # Generazione delle etichette di classe per il set di test utilizzando il kernel gaussiano e il sigma ottimo corrente
    pred = pnn(X_train, Y_train, X_test, gaussian, sigma_opt)

    # Calcolo delle metriche di performance
    accuracy = accuracy_score(Y_test.values, pred)
    accuracy_100 = "{:.2%}".format(accuracy)
    f1 = "{:.2%}".format(f1_score(Y_test.values, pred, average='weighted'))
    precision = "{:.2%}".format(precision_score(Y_test.values, pred, average='micro'))
    recall = "{:.2%}".format(recall_score(Y_test.values, pred, average='micro'))

    # Aggiunta delle statistiche di performance per la combinazione corrente di kernel, sigma e lingua al DataFrame results
    results.loc[len(results)] = ['Gaussian', sigma_opt, lingua, accuracy, accuracy_100, f1, precision, recall]

    # Stampa del DataFrame results. Per un questione di stile elimino la colonna accuracy, è presente l'accuracy in percentuale
    print(results.drop(columns=['Accuracy']))
    print("---" * 100)

    # Creazione della matrice di confusione
    labels = [lingua, 'Mondo']
    nomefile = 'CM_test_'+ lingua +"vsMondo_A"+format(accuracy, '.2f')
    output_folder = path_principale + '/Codici PNN/Matrici Confusione/BABELE/XvsMondo/'

    create_confusion_matrix(Y_test, pred, labels, sigma_opt, "Gaussian", save_path=output_folder, filename=nomefile)

    # Trova i video con previsioni errate per la lingua corrente
    nomefile_pred_errate_lingua = f'train-test_video_pred_errate_{lingua}vsMondo'
    trova_video_pred_errati_global(etichette_salvate, Y_test, pred, output_folder_video_pred_err, nomefile_pred_errate_lingua)

nome_file_csv_lingua = 'linguevsMondo.csv'
csv_path = "/content/drive/Shareddrives/Progetti FVAB 22 23 - VSR & BABELE/Gruppi/Gruppo 22/Progetto BABELE/CSV_PNN_RESULT/"+nome_file_csv_lingua
results.to_csv(csv_path, index=False) #Creazione csv da dataframe su dati di test
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#      Kernel  Smoothing Param    Lingua Accuracy (%) F1-Score Precision  Recall
# 0  Gaussian         0.847294  Italiano       52.50%   48.61%    52.50%  52.50%
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------- DATAFRAME PREDIZIONI ERRATE GLOBAL --------------------------------------------------
#        Nome Video  True Label  Predicted Label
# ...

# %%
plt.rcParams['figure.figsize'] = [10, 5]
plt.subplot(121)
sns.lineplot(y=results['Accuracy'],x=results['Smoothing Param'],hue=results['Kernel'], marker='o');
plt.title('Accuracy for Different Kernels on Valid. set',loc='right');

plt.subplot(122)
sns.lineplot(y=results['F1-Score'],x=results['Smoothing Param'],hue=results['Kernel'], marker='s');
plt.title('F1-Score for Different Kernels on Valid. set',loc='left');

plt.show()

# %% [markdown]
# #### Applicazione su Validation - X vs Mondo BABELE

# %%
# Caricamento del dataset dei sigma ottimi
sigmaOttimi = pd.read_csv(path_principale + '/Codici PNN/Sigma ottimi/BABELE/XvsMondo/' + 'train-validation_sigma_ottimiXvsMondo.csv')

# Definizione delle lingue disponibili da confrontare con Mondo
lingue = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']

# Inizializzazione di un DataFrame vuoto per salvare le statistiche di performance del classificatore
results = pd.DataFrame(columns=['Kernel', 'Smoothing Param', 'Lingua', 'Accuracy', 'Accuracy (%)', 'F1-Score', 'Precision', 'Recall'])

# Definizione della cartella di destinazione per le previsioni errate
output_folder_video_pred_err = path_principale + '/Codici PNN/Previsioni Errate/BABELE/Distanze/XvsMondo/Validation'

# Iterazione su ogni lingua
for lingua in lingue:

    print("---" * 100)

    # Ottieni il sigma ottimo corrispondente alla lingua corrente dal DataFrame dei sigma ottimi
    sigma_opt = sigmaOttimi.loc[sigmaOttimi['Lingua'] == lingua, 'Sigma Ottimo'].values[0]

    # Caricamento dei dati per la lingua corrente
    X_train, Y_train, X_validation, Y_validation, etichette_salvate = carica_dataset_train_validation_XVsMondo(lingua, logging=False)

    # Generazione delle etichette di classe per il set di test utilizzando il kernel gaussiano e il sigma ottimo corrente
    pred = pnn(X_train, Y_train, X_validation, gaussian, sigma_opt)

    # Calcolo delle metriche di performance
    accuracy = accuracy_score(Y_validation.values, pred)
    accuracy_100 = "{:.2%}".format(accuracy)
    f1 = "{:.2%}".format(f1_score(Y_validation.values, pred, average='weighted'))
    precision = "{:.2%}".format(precision_score(Y_validation.values, pred, average='micro'))
    #recall = "{:.2%}".format(recall_score(Y_validation.values, pred, average='micro'))

    # Aggiunta delle statistiche di performance per la combinazione corrente di kernel, sigma e lingua al DataFrame results
    results.loc[len(results)] = ['Gaussian', sigma_opt, lingua, accuracy, accuracy_100, f1, precision, 0]

    # Stampa del DataFrame results. Per un questione di stile elimino la colonna accuracy, è presente l'accuracy in percentuale
    print(results.drop(columns=['Accuracy']))
    print("---" * 100)

    # Creazione della matrice di confusione
    labels = [lingua, 'Mondo']
    nomefile = 'CM_validation_'+ lingua +"vsMondo_A"+format(accuracy, '.2f')
    output_folder = path_principale + '/Codici PNN/Matrici Confusione/BABELE/XvsMondo/'
    create_confusion_matrix(Y_test, pred, labels, sigma_opt, "Gaussian", save_path=output_folder, filename=nomefile)

    # Trova i video con previsioni errate per la lingua corrente
    nomefile_pred_errate_lingua = f'train-validation_video_pred_errate_{lingua}vsMondo'
    trova_video_pred_errati_global(etichette_salvate, Y_validation, pred, output_folder_video_pred_err, nomefile_pred_errate_lingua)

# %% [markdown]
# ## Grafico accuratezze linguevsMondo

# %%
df_lingue = pd.read_csv("/content/drive/Shareddrives/Progetti FVAB 22 23 - VSR & BABELE/Gruppi/Gruppo 22/Progetto BABELE/CSV_PNN_RESULT/linguevsMondo.csv")

# Definiamo la funzione per rimuovere il simbolo percentuale dalle stringhe
def remove_percent(string):
    if isinstance(string, str):
        return float(string.strip('%'))
    return string

# Rimuoviamo il simbolo percentuale dalla colonna "Accuracy" di ogni DataFrame
df_lingue['Accuracy'] = df_lingue['Accuracy'].apply(lambda x: remove_percent(x))

print(df_lingue['Accuracy'])

# Crea un grafico a barre con le accuratezze massime e colori diversi per le distanze
labels = ['Italiano', 'Inglese', 'Tedesco', 'Spagnolo', 'Olandese', 'Russo', 'Giapponese', 'Francese']
accuracies = [
    df_lingue['Accuracy'].values[0] *100,
    df_lingue['Accuracy'].values[1] *100,
    df_lingue['Accuracy'].values[2] *100,
    df_lingue['Accuracy'].values[3] *100,
    df_lingue['Accuracy'].values[4] *100,
    df_lingue['Accuracy'].values[5] *100,
    df_lingue['Accuracy'].values[6] *100,
    df_lingue['Accuracy'].values[7] *100
]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

# Ordina le lingue in base all'accuratezza in ordine decrescente
sorted_data = sorted(zip(labels, accuracies), key=lambda x: x[1], reverse=True)
labels, accuracies = zip(*sorted_data)

plt.bar(labels, accuracies, color=colors)

# Aggiungi il valore dell'accuratezza sopra ogni barra
for i, v in enumerate(accuracies):
    plt.text(i, v, str(v) + "%", ha='center', va='bottom', fontsize=7)

# Aggiungi titolo, etichette degli assi e griglia
plt.title('Accuratezza Lingue vs Mondo')
plt.xlabel('Lingua')
plt.ylabel('Accuratezza')
plt.grid(False)

# Diminuisci la dimensione delle label sull'asse x
plt.xticks(fontsize=7)

# Diminuisci la dimensione delle label sull'asse y
plt.yticks(fontsize=7)

# Mostra il grafico
plt.show()
# Out:
# 0    0.525
# 1    0.800
# 2    0.875
# 3    0.500
# 4    0.650
# 5    0.850
# 6    0.650
# 7    0.600
# Name: Accuracy, dtype: float64

# %%
# Estrai l'accuratezza massima di ciascun DataFrame
max_acc_city = df_city['Accuracy'].max()
max_acc_eucl = df_eucl['Accuracy'].max()
max_acc_cheby = df_cheby['Accuracy'].max()
max_acc_cosine = df_cosine['Accuracy'].max()

# Crea un grafico a barre con le accuratezze massime e colori diversi per le distanze
labels = ['Cityblock', 'Euclidean', 'Chebyshev', 'Cosine']
accuracies = [max_acc_city, max_acc_eucl, max_acc_cheby, max_acc_cosine]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Imposta i colori delle barre
plt.bar(labels, accuracies, color=colors)

# Aggiungi titolo, etichette degli assi e griglia
plt.title('Accuratezza dei DataFrame')
plt.xlabel('Metrica di distanza')
plt.ylabel('Accuratezza')
plt.grid(True)

# Mostra il grafico
plt.show()

# Trova l'indice della riga con l'accuratezza massima per ciascun DataFrame
max_idx_city = df_city['Accuracy'].idxmax()
max_idx_eucl = df_eucl['Accuracy'].idxmax()
max_idx_cheby = df_cheby['Accuracy'].idxmax()
max_idx_cosine = df_cosine['Accuracy'].idxmax()

# Seleziona le righe corrispondenti agli indici trovati
max_row_city = df_city.loc[max_idx_city]
max_row_eucl = df_eucl.loc[max_idx_eucl]
max_row_cheby = df_cheby.loc[max_idx_cheby]
max_row_cosine = df_cosine.loc[max_idx_cosine]

# Concatena le righe selezionate in un unico DataFrame
max_df = pd.concat([max_row_city, max_row_eucl, max_row_cheby, max_row_cosine], axis=1)

# Stampa il DataFrame con le righe contenenti i valori massimi di accuratezza
print("Le righe contenenti i valori massimi di accuratezza sono:")
print(max_df)
